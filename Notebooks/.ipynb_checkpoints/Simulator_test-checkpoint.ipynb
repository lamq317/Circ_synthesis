# %%
####Testing the simulation of circuits after compilation with BQSkit...

import os
from timeit import default_timer as timer
import pickle
import numpy as np
from scipy.linalg import expm
import scipy
import sys
sys.path.append('./utils/')


import logging
from bqskit.compiler import Compiler
from bqskit.passes import ForEachBlockPass
from bqskit.passes import QSearchSynthesisPass
from bqskit.passes import QFASTDecompositionPass
from bqskit.passes import ScanningGateRemovalPass
from bqskit.passes import ToU3Pass
from bqskit.passes import ToVariablePass
from bqskit.passes import LEAPSynthesisPass
from bqskit.passes import QSearchSynthesisPass
from bqskit.passes import UnfoldPass
from bqskit.passes import SimpleLayerGenerator
from bqskit.ir.gates import VariableUnitaryGate
from bqskit import Circuit

from bqskit.ir.lang.qasm2.qasm2 import OPENQASM2Language
from bqskit import MachineModel
from bqskit.ir.gates import CZGate, RZGate, SXGate, RXGate, RYGate
from bqskit import compile
from cirq.contrib.qasm_import import circuit_from_qasm
import cirq

# %%
import scipy.io as spio


def loadMat(mol,path):
    fname=path+f'generators_noesy_{mol}.mat'

    return spio.loadmat(fname, squeeze_me=True)

def EmbedInU(TarMat):

    Dim = TarMat.shape[0]

    UR = scipy.linalg.sqrtm(np.eye(Dim)-np.dot(TarMat,TarMat.conjugate().T))
    LL = scipy.linalg.sqrtm(np.eye(Dim)-np.dot(TarMat.conjugate().T,TarMat))
    
    U_meth = np.zeros([2*Dim,2*Dim],dtype=complex)
    U_meth[0:Dim,0:Dim] = TarMat
    U_meth[0:Dim,Dim:2*Dim]=UR
    U_meth[Dim:2*Dim,0:Dim]=LL
    U_meth[Dim:2*Dim,Dim:2*Dim]=-TarMat.conjugate().T

    return U_meth

def Umetric(TarMat):
    dim = TarMat.shape[0]
    
    return np.linalg.norm(np.dot(TarMat.conj().T,TarMat)-np.eye(dim))


def run_simp_layer_flow_example(in_circuit,
        amount_of_workers: int = 10, synt_pass = QSearchSynthesisPass
) -> tuple[Circuit, float]:
    
    num_multistarts = 32
   
    instantiate_options = {
        'method': 'qfactor',
        'multistarts': num_multistarts,
    }

    # Prepare the compilation passes
    #SimpleLayerGenerator(two_qudit_gate=CNOTGate, single_qudit_gate_1=U3Gate, single_qudit_gate_2=None, initial_layer_gate=None)

    passes = [

        # Split the circuit into partitions
       #QSearchSynthesisPass(instantiate_options=instantiate_options),
       synt_pass(layer_generator=SimpleLayerGenerator(two_qudit_gate=VariableUnitaryGate(2),single_qudit_gate_1=VariableUnitaryGate(1)),
                 success_threshold=1e-3,max_layer=5000,instantiate_options=instantiate_options)
       
       #QSearchSynthesisPass(layer_generator=LayerGenDef.AltLayer(),instantiate_options=instantiate_options)

    ]
    # Create the compilation task

    with Compiler(
        num_workers=amount_of_workers,
        runtime_log_level=logging.INFO,
    ) as compiler:

        print('Starting flow using QFactor instantiation')
        start = timer()
        out_circuit = compiler.compile(in_circuit, passes)
        end = timer()
        run_time = end - start

    return out_circuit, run_time


def SimulateBlock(bqskit_circ,n_flag,reps=1000,gate_set={CZGate(), RZGate(), SXGate()},noise=None):
    """
    Simulate post-selected samples from a Block-encoding unitary using cirq. Assuming that the target n-qubit matrix is block encoded in the 
    upper-left block of the unitary, this corresponds to post-select the measurement outcomes in the last n-qubits of the circuit.
    Args:
    bqskit_circ: result of circuit synthesis
    n_flag: number of flag qubits for the block encoding
    gate_set: the target gate set to perform the compilation
    """

    model = MachineModel(out_circ.num_qudits, gate_set=gate_set)

    inst_circuit = compile(out_circ, model=model)
    lang = OPENQASM2Language()
    qasm = lang.encode(inst_circuit)

    cirq_circ = circuit_from_qasm(qasm)
    qubits = sorted(cirq_circ.all_qubits())
    
    Nqubs = len(cirq_circ.all_qubits())

    n_sys = Nqubs - n_flag
    #qubits = cirq.LineQubit.range(Nqubs)
    control_register = qubits[0:n_flag]
    target_register = qubits[n_flag:]
    
    
    cirq_circ.append(cirq.measure(*control_register, key='control')) 
    cirq_circ.append(cirq.measure(*target_register, key='target'))
    
    
    simulator = cirq.Simulator()
    result = simulator.run(cirq_circ, repetitions=reps)
    
    # Step 4: Post-select results based on control register measurements
    control_measurements = result.measurements['control']
    target_measurements = result.measurements['target']
    
    # Post-select where control register is [0, 0] (or any desired condition)
    #post_selected_indices = np.where((control_measurements[:, 0] == 0) & (control_measurements[:, 1] == 0))[0]
    post_selected_indices = np.where((control_measurements[:] == [0]*n_flag))[0]
    post_selected_target_measurements = target_measurements[post_selected_indices]

    return post_selected_target_measurements

    
def EstimatePolarization(Measurements):
    """
    Estimate the expectation value of S_{z} = \sum_{n}\sigma^{(z)}_{n} from a list of Measurements
    """
    nqubs = len(Measurements[0])

    Tot_pol=0.0
    for i in range(len(Measurements)):

        m = 0.0
        for j in range(nqubs):
            res=Measurements[i][j]
            m+=(-1.0)**res

        Tot_pol+=m

    return Tot_pol/len(Measurements)

def UniformStatePrep(loc,nqubs):
    """
    Given an array of nqubs qubits, construct circuit that prepares a uniform superposition state supported on N qubits,
    whose location in the linear qubit array is determined by loc
    """
    cicuit = cirq.Circuit()
    Qubs = cirq.LineQubit.range(nqubs)

    for i in loc:
        circuit.append(cirq.H(Qubs[i]))

    return circuit

def SimulateFIDcirc(bqskit_circ,n_flag,LocSzs=None,reps=1000,gate_set={CZGate(), RZGate(), SXGate()},noise=None):
    """
    Perform the circuit simulation for estimation of FID.
    Args:
    bqskit_circ: result of circuit synthesis
    n_flag: number of flag qubits for the block encoding
    LocSzs: Array that contains indexes of qubits in the circuit that enumerate the Sz basis. If not given,
    it defaults to 0,1,...,log(N)-1, N being the number of spins being simulated
    reps: the number of circuit shots
    gate_set: the target gate set to perform the compilation
    noise: noise model assumed for the cirq simulator, if None, no noise is added.
    """

    model = MachineModel(out_circ.num_qudits, gate_set=gate_set)

    inst_circuit = compile(out_circ, model=model)
    lang = OPENQASM2Language()
    qasm = lang.encode(inst_circuit)

    cirq_circ = circuit_from_qasm(qasm)
    qubits = sorted(cirq_circ.all_qubits())
    
    nqubs = len(qubits)

    if LocSzs==None:
        NSz = int((nqubs-1)//2) #The assumption is that there is only one flag qubit
        NqubSz = np.log2(NSz)
        LocSzs = [i for i in range(NqubSz)]
        
    
    PrepareCirc = UniformStatePrep(locSzs,nqubs)

    FullCirc = cirq.Circuit(PrepareCirc+cirq_circ+PrepareCirc)

    return FullCirc

# %%
for i in range(0,1):
    print(i)
# Out:
# 0

# %%
[i for i in range(1)]
# Out:
# [0]

# %%
test=UniformStatePrep(0,3,5)

# %%
len(test.all_qubits())
# Out:
# 3

# %%
circuit = cirq.Circuit()
Qubs = cirq.LineQubit.range(3)

# %%
cirq.H(Qubs[0])
# Out:
# cirq.H(cirq.LineQubit(0))

# %%
###Synthesis of circuit...
n=2

Herm = np.random.rand(2**n,2**n)
Herm=Herm+Herm.T

TarMat = expm(-1j*Herm)

Umat = EmbedInU(TarMat)

# %%
Umetric(Umat)
# Out:
# 9.858975467028711e-09

# %%
Circuit.from_unitary(Umat)
# Out:
# Circuit(3)
# 	[ConstantUnitaryGate@(0, 1, 2), ConstantUnitaryGate@(0, 1, 2), ConstantUnitaryGate@(0, 1, 2)]

# %%
out_circ,run_time = run_simp_layer_flow_example(Circuit.from_unitary(Umat))
# Out:
# Started outgoing thread.
# Registered worker 0.
# Registered worker 1.
# Registered worker 2.
# Registered worker 3.
# Registered worker 4.
# Registered worker 5.
# Registered worker 6.
# Registered worker 7.
# Registered worker 8.
# Registered worker 9.
# Node has spawned 10 workers.
# Starting flow using QFactor instantiation
# Connected to client.
# AttachedServer running...
# New CompilationTask: db09d416-c911-4d30-a553-4bfeb17b67ce.
# Finished: db09d416-c911-4d30-a553-4bfeb17b67ce.
# Responding to request for task db09d416-c911-4d30-a553-4bfeb17b67ce.
# Shutting down node.
# Shutting down node.
# Shutting down node.

# %%
#out_circ

# %%
from bqskit.ir.gates import CNOTGate

# %%
from bqskit.ir.gates import RYYGate
from bqskit.ir.gates import SqrtISwapGate, SycamoreGate

from bqskit.ir.gates import ZZGate
quantinuum_like_gate_set = {ZZGate(), RZGate(), SXGate()}
cirq_gate_set = {SqrtISwapGate(), SycamoreGate(), CZGate(), RZGate(), SXGate()}


gate_set={CNOTGate(), RZGate(), RXGate(), RYGate()}

model = MachineModel(out_circ.num_qudits, gate_set=quantinuum_like_gate_set)

inst_circuit = compile(out_circ, model=model)
# Out:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>:: optimize
#  0:   _rust_begin_unwind
# 4: <bqskitrs::ir:: inst :: qfactor1::: QFactorInstantiatorcore as bqskitrs::ir::inst::::panickingInstantiate::>panic_fmt::instantiate
#
#       52: : bqskitrs::python::coreinstantiators::::panickingqfactor::::panic_
# ::<impl   bqskitrs ::3python: ::instantiators::<bqskitrs::qfactorir::::PyQFactorInstantiatoroperation::>Operation:: __pymethod_instantiate__
# as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
# Process Process-1:
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8Traceback (most recent call last):
# : __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
#    6: _method_vectorcall_VARARGS_KEYWORDS
# Process Process-6:
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: Process Process-9:
# _PyEval_EvalCode
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   18: _run_mod  File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#
#   19: _PyRun_SimpleStringFlags
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   20: _pymain_run_command
#    File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#  21: _Py_RunMain
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   22:   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
# _main
#   23  File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# : <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
# Process Process-10:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:457, in Compiler._send_recv(self, msg, payload)
#     455     self.conn.send((msg, payload))
# --> 457     return self._recv_handle_log_error()
#     459 except Exception as e:
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:471, in Compiler._recv_handle_log_error(self)
#     470 while to_return is None or self.conn.poll():
# --> 471     msg, payload = self.conn.recv()
#     473     if msg == RuntimeMessage.LOG:
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:249, in _ConnectionBase.recv(self)
#     248 self._check_readable()
# --> 249 buf = self._recv_bytes()
#     250 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:413, in Connection._recv_bytes(self, maxsize)
#     412 def _recv_bytes(self, maxsize=None):
# --> 413     buf = self._recv(4)
#     414     size, = struct.unpack("!i", buf.getvalue())
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:382, in Connection._recv(self, size, read)
#     381 if remaining == size:
# --> 382     raise EOFError
#     383 else:
#
# EOFError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[46], line 13
#       9 gate_set={CNOTGate(), RZGate(), RXGate(), RYGate()}
#      11 model = MachineModel(out_circ.num_qudits, gate_set=quantinuum_like_gate_set)
# ---> 13 inst_circuit = compile(out_circ, model=model)
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compile.py:629, in compile(input, model, optimization_level, max_synthesis_size, synthesis_epsilon, error_threshold, error_sim_size, compiler, seed, with_mapping, **compiler_kwargs)
#     626     in_circuit = Circuit(1)
#     628 # Perform the compilation
# --> 629 out, data = compiler.compile(in_circuit, workflow, True)
#     631 # Log error if necessary
#     632 if error_threshold is not None:
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:420, in Compiler.compile(self, task_or_circuit, workflow, request_data, logging_level, max_logging_depth)
#     405     warnings.warn(
#     406         'Manually constructing and compiling CompilationTasks'
#     407         ' is deprecated. Instead, call compile directly with'
#    (...)
#     410         DeprecationWarning,
#     411     )
#     413 task_id = self.submit(
#     414     task_or_circuit,
#     415     workflow,
#    (...)
#     418     max_logging_depth,
#     419 )
# --> 420 result = self.result(task_id)
#     422 # Ensure arrival of all log messages
#     423 time.sleep(0.05 if self.p is not None else 0.5)
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:331, in Compiler.result(self, task_id)
#     328     task_id = task_id.task_id
#     329 assert isinstance(task_id, uuid.UUID)
# --> 331 msg, payload = self._send_recv(RuntimeMessage.REQUEST, task_id)
#     332 if msg != RuntimeMessage.RESULT:
#     333     raise RuntimeError(f'Unexpected message type: {msg}.')
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:462, in Compiler._send_recv(self, msg, payload)
#     460 self.conn = None
#     461 self.close()
# --> 462 raise RuntimeError('Server connection unexpectedly closed.') from e
#
# RuntimeError: Server connection unexpectedly closed.

# %%
SimulateBlock(out_circ,1)
# Out:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
# Process Process-2:
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
# Process Process-5:
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
# Process Process-10:
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
# Traceback (most recent call last):
# Process Process-11:
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
# Traceback (most recent call last):
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:457, in Compiler._send_recv(self, msg, payload)
#     455     self.conn.send((msg, payload))
# --> 457     return self._recv_handle_log_error()
#     459 except Exception as e:
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:471, in Compiler._recv_handle_log_error(self)
#     470 while to_return is None or self.conn.poll():
# --> 471     msg, payload = self.conn.recv()
#     473     if msg == RuntimeMessage.LOG:
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:249, in _ConnectionBase.recv(self)
#     248 self._check_readable()
# --> 249 buf = self._recv_bytes()
#     250 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:413, in Connection._recv_bytes(self, maxsize)
#     412 def _recv_bytes(self, maxsize=None):
# --> 413     buf = self._recv(4)
#     414     size, = struct.unpack("!i", buf.getvalue())
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:382, in Connection._recv(self, size, read)
#     381 if remaining == size:
# --> 382     raise EOFError
#     383 else:
#
# EOFError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 SimulateBlock(out_circ,1)
#
# Cell In[38], line 82, in SimulateBlock(bqskit_circ, n_flag, reps, gate_set, noise)
#      71 """
#      72 Simulate post-selected samples from a Block-encoding unitary using cirq. Assuming that the target n-qubit matrix is block encoded in the
#      73 upper-left block of the unitary, this corresponds to post-select the measurement outcomes in the last n-qubits of the circuit.
#    (...)
#      77 gate_set: the target gate set to perform the compilation
#      78 """
#      80 model = MachineModel(out_circ.num_qudits, gate_set=gate_set)
# ---> 82 inst_circuit = compile(out_circ, model=model)
#      83 lang = OPENQASM2Language()
#      84 qasm = lang.encode(inst_circuit)
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compile.py:629, in compile(input, model, optimization_level, max_synthesis_size, synthesis_epsilon, error_threshold, error_sim_size, compiler, seed, with_mapping, **compiler_kwargs)
#     626     in_circuit = Circuit(1)
#     628 # Perform the compilation
# --> 629 out, data = compiler.compile(in_circuit, workflow, True)
#     631 # Log error if necessary
#     632 if error_threshold is not None:
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:420, in Compiler.compile(self, task_or_circuit, workflow, request_data, logging_level, max_logging_depth)
#     405     warnings.warn(
#     406         'Manually constructing and compiling CompilationTasks'
#     407         ' is deprecated. Instead, call compile directly with'
#    (...)
#     410         DeprecationWarning,
#     411     )
#     413 task_id = self.submit(
#     414     task_or_circuit,
#     415     workflow,
#    (...)
#     418     max_logging_depth,
#     419 )
# --> 420 result = self.result(task_id)
#     422 # Ensure arrival of all log messages
#     423 time.sleep(0.05 if self.p is not None else 0.5)
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:331, in Compiler.result(self, task_id)
#     328     task_id = task_id.task_id
#     329 assert isinstance(task_id, uuid.UUID)
# --> 331 msg, payload = self._send_recv(RuntimeMessage.REQUEST, task_id)
#     332 if msg != RuntimeMessage.RESULT:
#     333     raise RuntimeError(f'Unexpected message type: {msg}.')
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:462, in Compiler._send_recv(self, msg, payload)
#     460 self.conn = None
#     461 self.close()
# --> 462 raise RuntimeError('Server connection unexpectedly closed.') from e
#
# RuntimeError: Server connection unexpectedly closed.

# %%
post_results = SimulateBlock(out_circ,1,reps=1000)
# Out:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
# stack backtrace:
# thread '<unnamed>' panicked at src/ir/gates/optimize.rs:8:9:
# not implemented
# stack backtrace:
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#       0: 4_rust_begin_unwind
# : <bqskitrs::ir :: inst ::1qfactor: ::core::panickingQFactorInstantiator::panic_fmt
# as bqskitrs::ir::inst::Instantiate> :: instantiate
# 2: core::panicking::panic
#   5: bqskitrs::python::   instantiators3::: qfactor::_::<bqskitrs<::implir ::bqskitrsoperation::::pythonOperation:: instantiatorsas:: qfactorbqskitrs::::PyQFactorInstantiatorir::gates>::::optimize__pymethod_instantiate__::
# Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    0: _rust_begin_unwind
#    1: core::panicking::panic_fmt
#    2: core::panicking::panic
#    3: <bqskitrs::ir::operation::Operation as bqskitrs::ir::gates::optimize::Optimize>::optimize
#    4: <bqskitrs::ir::inst::qfactor::QFactorInstantiator as bqskitrs::ir::inst::Instantiate>::instantiate
#    5: bqskitrs::python::instantiators::qfactor::_::<impl bqskitrs::python::instantiators::qfactor::PyQFactorInstantiator>::__pymethod_instantiate__
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#    15 :  __PyEval_EvalFrameDefault6: _method_vectorcall_VARARGS_KEYWORDS
#
#     7 : __PyEval_EvalFrameDefault
# 16 : __PyEval_Vector
#    17 : 8_PyEval_EvalCode:
# __PyFunction_Vectorcall
#   18:    9: _run_mod__PyEval_EvalFrameDefault
#
#   19 :  _PyRun_SimpleStringFlags10
# : _gen_send_ex2
# 20 : _pymain_run_command
# 11: _gen_send
#     2112: : _Py_RunMain_method_vectorcall_O
#
#     1322: : __PyEval_EvalFrameDefault_main
#
#   14: __PyFunction_Vectorcall
#     1523: : __PyEval_EvalFrameDefault<unknown>
#      166: : _method_vectorcall_VARARGS_KEYWORDS
# __PyEval_Vector
#
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
#      177: : _PyEval_EvalCode__PyEval_EvalFrameDefault
#
#      188: : _run_mod__PyFunction_Vectorcall
#
#   19: _PyRun_SimpleStringFlags
#    9 : 20__PyEval_EvalFrameDefault:
# _pymain_run_command
#   21  10: _gen_send_ex2: _Py_RunMain
#
#     2211: : _main_gen_send
#
#   12:  _method_vectorcall_O
# 23:  <unknown>
# 13note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
# : __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   Process Process-11:
# 19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
# Process Process-6:
# Process Process-9:
#    6: _method_vectorcall_VARARGS_KEYWORDS
#    7: __PyEval_EvalFrameDefault
#    8: __PyFunction_Vectorcall
#    9: __PyEval_EvalFrameDefault
#   10: _gen_send_ex2
#   11: _gen_send
#   12: _method_vectorcall_O
#   13: __PyEval_EvalFrameDefault
#   14: __PyFunction_Vectorcall
#   15: __PyEval_EvalFrameDefault
#   16: __PyEval_Vector
#   17: _PyEval_EvalCode
#   18: _run_mod
#   19: _PyRun_SimpleStringFlags
#   20: _pymain_run_command
#   21: _Py_RunMain
#   22: _main
#   23: <unknown>
# note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.
# Process Process-12:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
# pyo3_runtime.PanicException: not implemented
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
# Traceback (most recent call last):
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/luismartinezmartinez/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 631, in start_worker
#     _worker._loop()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 230, in _loop
#     self._try_step_next_ready_task()
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/worker.py", line 378, in _try_step_next_ready_task
#     future = task.step(self._get_desired_result(task))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 93, in step
#     to_return = self.coro.send(send_val)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/runtime/task.py", line 108, in run
#     return self.fnargs[0](*self.fnargs[1], **self.fnargs[2])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/circuit.py", line 2868, in instantiate
#     instantiater.multi_start_instantiate_inplace(self, target, multistarts)
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in multi_start_instantiate_inplace
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiater.py", line 109, in <listcomp>
#     params_list = [self.instantiate(circuit, target, x0) for x0 in starts]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/luismartinezmartinez/BQSKit/lib/python3.11/site-packages/bqskit/ir/opt/instantiaters/qfactor.py", line 52, in instantiate
#     return QFactorInstantiatorNative.instantiate(self, circuit, target, x0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# pyo3_runtime.PanicException: not implemented
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:457, in Compiler._send_recv(self, msg, payload)
#     455     self.conn.send((msg, payload))
# --> 457     return self._recv_handle_log_error()
#     459 except Exception as e:
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:471, in Compiler._recv_handle_log_error(self)
#     470 while to_return is None or self.conn.poll():
# --> 471     msg, payload = self.conn.recv()
#     473     if msg == RuntimeMessage.LOG:
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:249, in _ConnectionBase.recv(self)
#     248 self._check_readable()
# --> 249 buf = self._recv_bytes()
#     250 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:413, in Connection._recv_bytes(self, maxsize)
#     412 def _recv_bytes(self, maxsize=None):
# --> 413     buf = self._recv(4)
#     414     size, = struct.unpack("!i", buf.getvalue())
#
# File ~/anaconda3/lib/python3.11/multiprocessing/connection.py:382, in Connection._recv(self, size, read)
#     381 if remaining == size:
# --> 382     raise EOFError
#     383 else:
#
# EOFError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 post_results = SimulateBlock(out_circ,1,reps=1000)
#
# Cell In[176], line 82, in SimulateBlock(bqskit_circ, n_flag, reps, gate_set, noise)
#      71 """
#      72 Simulate post-selected samples from a Block-encoding unitary using cirq. Assuming that the target n-qubit matrix is block encoded in the
#      73 upper-left block of the unitary, this corresponds to post-select the measurement outcomes in the last n-qubits of the circuit.
#    (...)
#      77 gate_set: the target gate set to perform the compilation
#      78 """
#      80 model = MachineModel(out_circ.num_qudits, gate_set=gate_set)
# ---> 82 inst_circuit = compile(out_circ, model=model)
#      83 lang = OPENQASM2Language()
#      84 qasm = lang.encode(inst_circuit)
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compile.py:629, in compile(input, model, optimization_level, max_synthesis_size, synthesis_epsilon, error_threshold, error_sim_size, compiler, seed, with_mapping, **compiler_kwargs)
#     626     in_circuit = Circuit(1)
#     628 # Perform the compilation
# --> 629 out, data = compiler.compile(in_circuit, workflow, True)
#     631 # Log error if necessary
#     632 if error_threshold is not None:
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:420, in Compiler.compile(self, task_or_circuit, workflow, request_data, logging_level, max_logging_depth)
#     405     warnings.warn(
#     406         'Manually constructing and compiling CompilationTasks'
#     407         ' is deprecated. Instead, call compile directly with'
#    (...)
#     410         DeprecationWarning,
#     411     )
#     413 task_id = self.submit(
#     414     task_or_circuit,
#     415     workflow,
#    (...)
#     418     max_logging_depth,
#     419 )
# --> 420 result = self.result(task_id)
#     422 # Ensure arrival of all log messages
#     423 time.sleep(0.05 if self.p is not None else 0.5)
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:331, in Compiler.result(self, task_id)
#     328     task_id = task_id.task_id
#     329 assert isinstance(task_id, uuid.UUID)
# --> 331 msg, payload = self._send_recv(RuntimeMessage.REQUEST, task_id)
#     332 if msg != RuntimeMessage.RESULT:
#     333     raise RuntimeError(f'Unexpected message type: {msg}.')
#
# File ~/BQSKit/lib/python3.11/site-packages/bqskit/compiler/compiler.py:462, in Compiler._send_recv(self, msg, payload)
#     460 self.conn = None
#     461 self.close()
# --> 462 raise RuntimeError('Server connection unexpectedly closed.') from e
#
# RuntimeError: Server connection unexpectedly closed.

# %%
len(post_results)
# Out:
# 5000

# %%
EstimatePolarization(post_results)
# Out:
# 0.1624

# %%
####Expected exact result...
TotZ = np.array([[1.0,0.0],[0.0,-1.0]])
psievol = np.dot(TarMat,[1.0,0.0])

np.dot(psievol.conjugate().T,np.dot(TotZ,psievol))
# Out:
# (0.15555903062724383+0j)
